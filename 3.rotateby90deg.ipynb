# %% [markdown]
# rotate matix by 90 deg
# ![image.png](attachment:image.png)

# %% [markdown]
# there is a pattern
# ![WhatsApp Image 2025-08-14 at 15.56.29_a09e8b82.jpg](<attachment:WhatsApp Image 2025-08-14 at 15.56.29_a09e8b82.jpg>)

# %%
def rotateby90(matrix):
    n=len(matrix)
    ans=[[0]* n for _ in range(n)]

    for i in range(n):
        for j in range(n):
            ans[j][n-1-i]=matrix[i][j]

    for i in range(n):
        matrix[i]=ans[i]
    return matrix

if __name__=="__main__":
    matrix=[[1,2,3],[4,5,6],[7,8,9]]
    print(rotateby90(matrix))
# Out:
# [[7, 4, 1], [8, 5, 2], [9, 6, 3]]

# %% [markdown]
# here you take a ans a matrix and assign 0 to all the elem, then take each elem of original matirx and place then to yhe postion ans[j][n-1-i]
# then assign all the rotated values back to the original matrix ...
# TC=o(n^2)
# SC=O(n^2)

# %% [markdown]
# ![WhatsApp Image 2025-08-14 at 16.03.57_fbf53044.jpg](<attachment:WhatsApp Image 2025-08-14 at 16.03.57_fbf53044.jpg>)

# %% [markdown]
# optimal soln
# ![WhatsApp Image 2025-08-14 at 16.26.41_44f7f2d7.jpg](<attachment:WhatsApp Image 2025-08-14 at 16.26.41_44f7f2d7.jpg>)

# %% [markdown]
# 1.transpose and
# 2.reverse row
#
# transpose a[i][j]=a[j][i]
#
# reverse matrix[i][j],matrix[i][n-1-j]=matrix[i][n-1-j],matrix[i][j]

# %%
class Solution:
    def rotateMatrix(self, matrix):
        n=len(matrix)
        for i in range(n):
            for j in range(i):
                matrix[i][j],matrix[j][i]=matrix[j][i],matrix[i][j]


        for i in range(n):
            for j in range(n//2):
                matrix[i][j],matrix[i][n-1-j]=matrix[i][n-1-j],matrix[i][j]        
        return matrix
if __name__=="__main__":    
    matrix=[[1,2,3],[4,5,6],[7,8,9]]
    sol=Solution()
    print(sol.rotateMatrix(matrix))
# Out:
# [[7, 4, 1], [8, 5, 2], [9, 6, 3]]
